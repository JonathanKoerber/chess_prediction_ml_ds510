# %%
from chess_env_bitboard import BitBoardEnv
from dqn_agent import DQN_Agent
import numpy as np
import time
import random
# Out:
# 2024-02-09 22:44:34.224442: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-09 22:44:34.263370: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-09 22:44:34.263397: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-09 22:44:34.264474: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-09 22:44:34.270569: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
env = BitBoardEnv()
agent = DQN_Agent(env, state_shape=(12, 8, 8), num_actions=64)

# %%
num_episodes = 50
for episode in range(num_episodes):
    state = env.reset()
    done = env.done
    episode_experiences = []  # Accumulate experiences during the episode

    while not done:
        action = agent.choose_action(state)
        next_state, reward, done = env.step(action)
        episode_experiences.append((state, action, reward, next_state, done))
        state = next_state

    # Store experiences in the replay buffer
    for experience in episode_experiences:
        agent.store_experience(*experience)

    # Sample and train on a batch of experiences
    batch_size = 32  # Adjust the batch size as needed
    if len(agent.replay_buffer) >= batch_size:
        batch = np.random.choice(agent.replay_buffer, size=batch_size, replace=False)
        states, actions, rewards, next_states, dones = zip(*batch)
        agent.train(states, actions, rewards, next_states, dones)

    print(f"Episode {episode+1}/{num_episodes} done")
# Out:
# ...
# 1/1 [==============================] - 0s 15ms/step
# ...
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~/CityUSeattle/artificial_intel_for_data_sciecnce_DS510/team-project/chess_prediction_ml_ds510/venv/lib/python3.10/site-packages/tensorflow/python/framework/func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# ...

# %%
print(env.board)
print(env.step())
print(env.board)
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 print(env.board)
# ----> 2 print(env.step())
#       3 print(env.board)
#
# TypeError: BitBoardEnv.step() missing 1 required positional argument: 'action'
